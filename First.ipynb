# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(r"C:\AutoMPGmodels.xlsx")

# %%
dataset.shape
# Out:
# (392, 15)

# %%
dataset.head(3)
# Out:
#    GallonsPer100Miles  GallonsPer100MilesTo1981   MPG  Cylinders  \
# 0            5.555556                  5.555556  18.0          8
# 1            6.666667                  6.666667  15.0          8
# 2            5.555556                  5.555556  18.0          8
#
#    Displacement100ci  Horsepower100  Weight1000lb  Seconds0to60  Year  \
# 0               3.07           1.30         3.504          12.0    70
# 1               3.50           1.65         3.693          11.5    70
# 2               3.18           1.50         3.436          11.0    70
#
#    Year70To81  Origin  Origin.Eq.1  Origin.Eq.2  Origin.Eq.3  \
# 0           1       1            1            0            0
# 1           1       1            1            0            0
# 2           1       1            1            0            0
#
#                         Name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 0.5102040816326531

# %%
dataset.isnull().sum().sum()
# Out:
# 30

# %%
dataset.isnull().sum()
# Out:
# GallonsPer100Miles           0
# GallonsPer100MilesTo1981    30
# MPG                          0
# Cylinders                    0
# Displacement100ci            0
# Horsepower100                0
# Weight1000lb                 0
# Seconds0to60                 0
# Year                         0
# Year70To81                   0
# Origin                       0
# Origin.Eq.1                  0
# Origin.Eq.2                  0
# Origin.Eq.3                  0
# Name                         0
# dtype: int64

# %%
dataset.isnull()
# Out:
#      GallonsPer100Miles  GallonsPer100MilesTo1981    MPG  Cylinders  \
# 0                 False                     False  False      False
# 1                 False                     False  False      False
# 2                 False                     False  False      False
# 3                 False                     False  False      False
# 4                 False                     False  False      False
# ..                  ...                       ...    ...        ...
# 387               False                      True  False      False
# 388               False                      True  False      False
# 389               False                      True  False      False
# 390               False                      True  False      False
# 391               False                      True  False      False
#
#      Displacement100ci  Horsepower100  Weight1000lb  Seconds0to60   Year  \
# 0                False          False         False         False  False
# 1                False          False         False         False  False
# 2                False          False         False         False  False
# 3                False          False         False         False  False
# 4                False          False         False         False  False
# ..                 ...            ...           ...           ...    ...
# 387              False          False         False         False  False
# 388              False          False         False         False  False
# 389              False          False         False         False  False
# 390              False          False         False         False  False
# 391              False          False         False         False  False
#
#      Year70To81  Origin  Origin.Eq.1  Origin.Eq.2  Origin.Eq.3   Name
# 0         False   False        False        False        False  False
# 1         False   False        False        False        False  False
# 2         False   False        False        False        False  False
# 3         False   False        False        False        False  False
# 4         False   False        False        False        False  False
# ..          ...     ...          ...          ...          ...    ...
# 387       False   False        False        False        False  False
# 388       False   False        False        False        False  False
# 389       False   False        False        False        False  False
# 390       False   False        False        False        False  False
# 391       False   False        False        False        False  False
#
# [392 rows x 15 columns]

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# GallonsPer100Miles          0.000000
# GallonsPer100MilesTo1981    7.653061
# MPG                         0.000000
# Cylinders                   0.000000
# Displacement100ci           0.000000
# Horsepower100               0.000000
# Weight1000lb                0.000000
# Seconds0to60                0.000000
# Year                        0.000000
# Year70To81                  0.000000
# Origin                      0.000000
# Origin.Eq.1                 0.000000
# Origin.Eq.2                 0.000000
# Origin.Eq.3                 0.000000
# Name                        0.000000
# dtype: float64

# %%
sns.heatmap(dataset.notnull())
# Out:
# <Axes: >

# %%
sns.heatmap(dataset.isnull())
plt.show()
