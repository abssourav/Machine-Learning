# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(r"C:\AutoMPGmodels.xlsx")

# %%
dataset.head(25)
# Out:
#     GallonsPer100Miles  GallonsPer100MilesTo1981   MPG  Cylinders  \
# 0             5.555556                  5.555556  18.0        8.0
# 1             6.666667                  6.666667  15.0        8.0
# 2             5.555556                  5.555556  18.0        8.0
# 3             6.250000                  6.250000  16.0        8.0
# 4             5.882353                  5.882353  17.0        8.0
# 5             6.666667                  6.666667  15.0        8.0
# 6             7.142857                  7.142857  14.0        8.0
# 7             7.142857                  7.142857  14.0        8.0
# 8             7.142857                  7.142857  14.0        8.0
# 9             6.666667                  6.666667  15.0        8.0
# 10            6.666667                       NaN  15.0        8.0
# 11            7.142857                  7.142857  14.0        8.0
# 12            6.666667                  6.666667  15.0        8.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   GallonsPer100Miles        391 non-null    float64
#  1   GallonsPer100MilesTo1981  355 non-null    float64
#  2   MPG                       389 non-null    float64
#  3   Cylinders                 391 non-null    float64
#  4   Displacement100ci         384 non-null    float64
#  5   Horsepower100             387 non-null    float64
#  6   Weight1000lb              377 non-null    float64
#  7   Seconds0to60              385 non-null    float64
#  8   Year                      390 non-null    float64
#  9   Year70To81                390 non-null    float64
#  10  Origin                    389 non-null    float64
#  11  Origin.Eq.1               390 non-null    float64
#  12  Origin.Eq.2               390 non-null    float64
# ...

# %%
dataset.select_dtypes(include = "float64" ).columns
# Out:
# Index(['GallonsPer100Miles', 'GallonsPer100MilesTo1981', 'MPG', 'Cylinders',
#        'Displacement100ci', 'Horsepower100', 'Weight1000lb', 'Seconds0to60',
#        'Year', 'Year70To81', 'Origin', 'Origin.Eq.1', 'Origin.Eq.2'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = "mean")
arr = si.fit_transform(dataset[['GallonsPer100Miles', 'GallonsPer100MilesTo1981', 'MPG', 'Cylinders',
       'Displacement100ci', 'Horsepower100', 'Weight1000lb', 'Seconds0to60',
       'Year', 'Year70To81', 'Origin', 'Origin.Eq.1', 'Origin.Eq.2']])

# %%
new_data = pd.DataFrame(arr,columns = dataset.select_dtypes(include = "float64").columns)

# %%
new_data.head(25)
# Out:
#     GallonsPer100Miles  GallonsPer100MilesTo1981   MPG  Cylinders  \
# 0             5.555556                  5.555556  18.0        8.0
# 1             6.666667                  6.666667  15.0        8.0
# 2             5.555556                  5.555556  18.0        8.0
# 3             6.250000                  6.250000  16.0        8.0
# 4             5.882353                  5.882353  17.0        8.0
# 5             6.666667                  6.666667  15.0        8.0
# 6             7.142857                  7.142857  14.0        8.0
# 7             7.142857                  7.142857  14.0        8.0
# 8             7.142857                  7.142857  14.0        8.0
# 9             6.666667                  6.666667  15.0        8.0
# 10            6.666667                  4.884115  15.0        8.0
# 11            7.142857                  7.142857  14.0        8.0
# 12            6.666667                  6.666667  15.0        8.0
# ...
